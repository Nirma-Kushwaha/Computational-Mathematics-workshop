# %% [markdown]
# <a href="https://colab.research.google.com/github/Nirma-Kushwaha/Computational-Mathematics-workshop/blob/main/Workshop8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Solve the linear systems graphically.
a. x+3y=5
x-2y=-5
x+y=3

# %%
import numpy as np

import matplotlib.pyplot as plt

""" Part 1 - Problem 1: Solve linear systems graphically. """

# Generate 100 equidistant point between -5 to 5 for x

x = np.linspace(-5,5,100)

## Calculate y values for Equation 1 and 2

y1 = (5-x)/3

y2 = (5+x)/2

y3 = 3-x

## Generate a figure frame for plotting the lines

fig, ax = plt.subplots()

## Plot the two lines

ax.plot(x,y1, color='r')

ax.plot(x,y2, color='g')

ax.plot(x,y3, color='b')

## To decorate the plot, we insert equations.

ax.text(0.5,0.6, '$x+3y = 5$', color='r')

ax.text(-3,0.5,'$x-2y = -5$', color='g')

ax.text(1.2,2, '$x+y = 3$', color='b')

## Set the limits of the X & Y axes.

ax.set_xlim(-4,4)

ax.set_ylim(-2,6)

## Set property of X and Y axes, e.g., color and linewidth

ax.axvline(color='k',linewidth = 1)

ax.axhline(color='k',linewidth = 1)

## This option specifies the ticks based the list of numbers provided.

ax.set_xticks(list(range(-4,5)))

ax.set_aspect('equal')

ax.grid(True,ls=':')

plt.xlabel("X")

plt.ylabel("Y")

plt.show()

# %% [markdown]
# Task 1: Plot the graph for linear system b and write the point of intersection between three lines.
#
# b. 2x+3y=3
#
#    4x+6y=6
#
#    3x-2y=1

# %%
import numpy as np
import matplotlib.pyplot as plt
#Generate 100 equidistant point between -5 to 5 for x
x = np.linspace(-5,5,100)
# Calculate y values for Equation 1, 2 and 3
y1 = (3-2*x)/3
y2 = (6-4*x)/6
y3 = -(1-3*x)/2
## Generate a figure frame for plotting the lines
fig, ax = plt.subplots()
## Plot the two lines
ax.plot(x,y1, color='r')
ax.plot(x,y2, color='g')
ax.plot(x,y3, color='b')
## To decorate the plot, we insert equations.
ax.text(0.5,0.6, '$2x+3y = 3$', color='r')
ax.text(-3,0.5,'$4x+6y = 6$', color='g')
ax.text(1.2,2, '$3x-2y = 1$', color='b')
## Set the limits of the X & Y axes.
ax.set_xlim(-4,4)
ax.set_ylim(-2,6)
## Set property of X and Y axes, e.g., color and linewidth
ax.axvline(color='k',linewidth = 1)
ax.axhline(color='k',linewidth = 1)
## This option specifies the ticks based the list of numbers provided.
ax.set_xticks(list(range(-4,5)))
ax.set_aspect('equal')
ax.grid(True,ls=':')
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %% [markdown]
# Task 2:
#
# 1. Create a program that reads in two 5x6 numpy.arrays, adds them together, and then stores the result in a third 5x6 matrix. The program should then print out the first two matrices and the result matrix.

# %%
import numpy as np
A = np.random.randint(1, 11, (5, 6))
B = np.random.randint(1, 11, (5, 6))
C = A + B
print(A)
print(B)
print(C)
# Out:
# [[ 4  1 10  7  8  1]
#  [ 8  9  3  7  8  8]
#  [ 7  2  6  2  1  5]
#  [ 8  8  3  5  1  9]
#  [ 8  4 10  6  5  4]]
# [[ 2  8  4 10  9  1]
#  [ 3  1  2  7  2  2]
#  [10  5  6  5  2  5]
#  [ 1  5  6  1  6  9]
#  [ 7  6  3  7  2  7]]
# [[ 6  9 14 17 17  2]
#  [11 10  5 14 10 10]
#  [17  7 12  7  3 10]
#  [ 9 13  9  6  7 18]
#  [15 10 13 13  7 11]]

# %% [markdown]
# 2. Create a program that reads in three 2x3 numpy.arrays, subtracts the second from the first, and adds the third to the result. The program should then print out all three matrices and the result matrix.

# %%
import numpy as np
A = np.random.randint(1, 11, (2, 3))
B = np.random.randint(1, 11, (2, 3))
C = np.random.randint(1, 11, (2, 3))
D = (A - B) + C
print(A)
print(B)
print(C)
print(D)
# Out:
# [[3 7 7]
#  [8 8 4]]
# [[ 2 10  7]
#  [ 8  6  8]]
# [[ 3 10  2]
#  [10  5  9]]
# [[ 4  7  2]
#  [10  7  5]]

# %% [markdown]
# 3. Create a 4x4 matrix containing random numbers in the range of 1 to 20. Have the user prompted for a number, check that the imputed value is a number and then check if the number is in the matrix. If the number is in the matrix, return the number of times that number is in the matrix.

# %%
import numpy as np
A = np.random.randint(1, 21, (4,4))
print(A)
x = input("Enter number: ")
if x.isdigit():
    x = int(x)
    count = np.sum(A == x)
    print("Found", count, "time(s)" if count else "Not in matrix")
else:
    print("Invalid input")
# Out:
# [[ 8 13  2  2]
#  [ 3 15  3  8]
#  [ 5 12  5 13]
#  [ 7 15  9  9]]
# Enter number: 2
# Found 2 time(s)

# %% [markdown]
# Copy and run the following codes and write what the code does?
#
# 1. linalg.det(a): calculates the determinant of the matrix

# %%
import numpy as np

a=np.array([[1,2],[3,4]])

det_a=np.linalg.det(a)

print(det_a)
# Out:
# -2.0000000000000004

# %% [markdown]
# 2. linalg.matrix_rank(a): computes the rank of the matrix

# %%
import numpy as np

a=np.array([[1,2],[3,4]])
rank_a=np.linalg.matrix_rank(a)
print(rank_a)
# Out:
# 2

# %% [markdown]
# 3. linalg.inv(a): calculates the multiplicative inverse of a matrix

# %%
import numpy as np

a=np.array([[1,2],[3,4]])
a_inv=np.linalg.inv(a)
print(a_inv)
# Out:
# [[-2.   1. ]
#  [ 1.5 -0.5]]

# %% [markdown]
# 4. linalg.solve(a,b): solve a linear system of equations ax=b
#
# #given system
#
# 𝑥+2𝑦=1
#
# 3𝑥+5𝑦=2

# %%
a=np.array([[1,2],[3,4]])

b=np.array([1,2])

x=np.linalg.solve(a,b)

print(x)
# Out:
# [0.  0.5]

# %% [markdown]
# 5. linalg.pinv(a): compute the pseudo-inverse of a matrix.

# %%
import numpy as np
a=np.random.randn(3,2)
b=np.linalg.pinv(a)
np.allclose(a,np.dot(a,np.dot(b,a)))
# Out:
# True

# %% [markdown]
# Task 3:
#
# 1. Create a matrix 𝑨 of order 5 × 5 with random entries. Calculate the rank of the matrix 𝑨 to check the number of linearly independent columns or rows and to check if the matrix is invertible. What are the other ways to check if the matrix is invertible?

# %%
import numpy as np
#Create a 5x5 matrix with random entries
A = np.random.rand(5, 5)
#calculate rank
rank_A = np.linalg.matrix_rank(A)
#check if invertible (rank must be 5 for 5x5 matrix)
is_invertible = (rank_A ==5)
print("Matrix A:\n", A)
print("\nRank of A:", rank_A)
if is_invertible:
  print("Matrix A is invertible.")
else:
  print("Matrix A is Not invertible.")
# Out:
# Matrix A:
#  [[0.05023934 0.66084416 0.90913091 0.91694279 0.65644739]
#  [0.0589664  0.87835247 0.51039261 0.08209601 0.17755983]
#  [0.1704978  0.56074436 0.15784863 0.03627522 0.48085879]
#  [0.95743838 0.02501787 0.99685921 0.73300957 0.4116105 ]
#  [0.16622536 0.49898579 0.28176102 0.57046699 0.88287153]]
#
# Rank of A: 5
# Matrix A is invertible.

# %% [markdown]
# 2. Generate a matrix 𝑨 of order 5 × 5 with random entries and generate a vector (column) 𝒙 of length 5 with random entries. Calculate Matrix-vector product 𝒃 = 𝑨𝒙. Now, we have a linear system, i.e. the matrix 𝑨 and a vector 𝒃. Solve this Linear System.

# %%
import numpy as np
# Generate random 5x5 matrix A
A = np.random.rand(5, 5)
# Generate random column vector x (length 5)
x = np.random.rand(5, 1)
# Matrix-vector product b = Ax
b = np.dot(A, x)
# Solve linear system Ax = b
x_solved = np.linalg.solve(A, b)
print("Matrix A:\n", A)
print("\nVector x (original):\n", x)
print("\nVector b = Ax:\n", b)
print("\nSolution of Ax = b:\n", x_solved)
# Out:
# Matrix A:
#  [[0.37554798 0.53302107 0.72479512 0.84729579 0.79275876]
#  [0.72155641 0.62048149 0.72250148 0.13411618 0.26989137]
#  [0.62954749 0.40137285 0.88634695 0.49540429 0.62469642]
#  [0.38126212 0.33378888 0.75492953 0.64953655 0.55543466]
#  [0.86522392 0.51518923 0.16029224 0.35471167 0.48205745]]
#
# Vector x (original):
#  [[0.73723988]
#  [0.18242184]
#  [0.90951457]
#  [0.06550063]
#  [0.5891833 ]]
#
# Vector b = Ax:
#  [[1.55589398]
#  [1.47007534]
#  [1.74400215]
#  [1.39838931]
#  [1.18490152]]
#
# Solution of Ax = b:
#  [[0.73723988]
#  [0.18242184]
#  [0.90951457]
#  [0.06550063]
#  [0.5891833 ]]

# %% [markdown]
# 3. Solve the following system.
#
# 8x+3y−2z=9
#
# −4x+7y+5z==15
#
# 3x+4y−12z=35

# %%
import numpy as np

# Coefficient matrix
A = np.array([
    [8, 3, -2],
    [-4, 7, 5],
    [3, 4, -12]
])
# Right-hand side vector
b = np.array([9, 15, 35])
# Solve the system Ax = b
solution = np.linalg.solve(A, b)
print("Solution (x, y, z):")
print(solution)
print("\nx =", solution[0])
print("y =", solution[1])
print("z =", solution[2])
# Out:
# Solution (x, y, z):
# [-0.58226371  3.22870478 -1.98599767]
#
# x = -0.5822637106184365
# y = 3.2287047841306884
# z = -1.985997666277713

# %% [markdown]
# Task 4:
#
# 1. Consider the following 10 points in X-Y plane: (−3, −7.6), (−2,1), (−1, 4.8), (0, 5), (1, 2.8), (2, −0.6), (3, −4), (4, −6.2), (5, −6), (7, 6.4). Plot these points in X-Y plane. Connect the points to guess the polynomial. Once you guess your polynomial, formulate a Linear System and then solve it to find the coefficient of the polynomial. Finally, check if the polynomial fits along with the above given points.

# %%
import numpy as np
import matplotlib.pyplot as plt
# points
x = [-3,-2,-1,0,1,2,3,4,5,7]
y = [-7.6,1,4.8,5,2.8,-0.6,-4,-6.2,-6,6.4]
# find polynomial
coeff = np.polyfit(x, y, 9)
# plot curve
xp = np.linspace(min(x), max(x), 200)
yp = np.polyval(coeff, xp)
plt.scatter(x, y)
plt.plot(xp, yp)
plt.show()
