# %% [markdown]
# <a href="https://colab.research.google.com/github/Nirma-Kushwaha/Computational-Mathematics-workshop/blob/main/Workshop3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Example-1

# %%
#we need to improt matplotlib sub library pyplotlib

import matplotlib.pyplot as plt

# Then we need to have some x and y coordinate, for e.g we use lists

x=[1, 2, 3, 4]
y=[1, 4, 9, 16]

# we then tell python function to use plt to plot the graph

plt.plot(x,y)

# finally much like "print" we need to tell python to print the current graph.
plt.show()

# %% [markdown]
# Task 1: Run and document the effect of these settings have on pyplot’s graph presentation.
#
# plt.xlim(0,50)
# plt.ylim(0,50)
# plt.grid()

# %%
import matplotlib.pyplot as plt
#Apply axis limits
plt.xlim(0,50)
plt.ylim(0,50)
#Enable grid
plt.grid()
plt.show()

# %% [markdown]
# Example 2:

# %%
import matplotlib.pyplot as plt
x=[2, 3, 4, 5]

plt.plot(x)
#only one parameter ??

plt.show()

# %% [markdown]
# Example 3:

# %%
import matplotlib.pyplot as plt

x=[2, 3, 4, 5]

y=[3,4,5,6]

plt.plot(x, y, marker='o', color='red', linewidth=5)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('The Graph')
plt.show()

# %% [markdown]
# Example 4:

# %%
import matplotlib.pyplot as plt

x=[2, 3, 4, 5]

y=[3, 4, 5, 6]

plt.plot(x, y, marker='o', color='blue',label='line 1', linewidth=3)

plt.plot(x, marker='+', color='green',label='line 2', linewidth=2)

#function to add title
plt.title('Example 4') #Function to label axes
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
# Function to add a legend
plt.legend()
# function for the visibility of grid
plt.grid()
plt.show()

# %% [markdown]
# Task 2:
#
# The following table shows the different vehicles and the distance covered by them in the span of 5 days. Display the following table in line plot.
#
# a. Plot “days” in X- axis and “distance covered” in Y- axis.
#
# b. Title of the table “bike details in Plot”
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
#Data
days = [1, 2, 3, 4, 5]
distance = [ 50, 40, 70, 80, 20] # Enfield
# Plot
plt.plot(days, distance, marker='o')
# Axis labels
plt.xlabel('Days')
plt.ylabel('Distance covered (kms)')
plt.show()

# %%
import matplotlib.pyplot as plt
days = [1, 2, 3, 4, 5]
enfield = [50, 40, 70, 80, 20]
honda = [80, 20, 20, 50, 60]
yahama = [70, 20, 60, 40, 60]
ktm = [40, 20, 30, 70, 60]
#Ensure all lists are same length
print(len(days), len(enfield), len(honda), len(yahama), len(ktm))
#Plot all bikes
plt.plot(days, enfield, marker='o', label='Enfield')
plt.plot(days, honda, marker='o', label='Honda')
plt.plot(days, yahama, marker='o', label='Yahama')
plt.plot(days, ktm, marker='o', label='KTM')
#labels and title
plt.xlabel('Days')
plt.ylabel('Distance Covered (kms)')
plt.title('Bike Details in Plot')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 5 5 5 5 5

# %% [markdown]
# Example 5:

# %%
import matplotlib.pyplot as plt

#create a function to calculate y values

def function(x):

  result= 3*x+2

  return result

#defining empty lists

xCord=[]

yCord=[]

#loop over 10 values from 0 to 9, and calculate the matching values for
#y using the function


for i in range(0,10):

  xCord.append(i)
  yCord.append(function(i))



plt.plot(xCord,yCord, marker='x',color='red')

#function to add title

plt.title('Example 5')


#Function to label axes
plt.xlabel('X-axis')

plt.ylabel('Y-axis')


# function for the visibility of grid
plt.grid()

plt.show()

# %% [markdown]
# Example 6:

# %%
import matplotlib.pyplot as plt

# plot a line, implicitly creating a subplot(111)

x=[1,2,3]
y=[4,5,6]
#plt.subplot(nRows,nColumns,index)

# nrows/nColumns number of rows/columns of graphs in the output section

#index position of the graph

plt.subplot(2,2,1)

#subplot(2,2,1) means there will be 2 graphs in row and 2 in columns and index 1 means this graph will be at the first position


plt.plot(x,y, marker='*', color='red')


plt.subplot(2,2,2)
plt.plot(x,y, marker='x', color='green')


plt.subplot(2,2,3)
plt.plot(x,y, marker='^', color='blue')


plt.subplot(2,2,4)
plt.plot(x,y, marker='+', color='yellow')

# %% [markdown]
# 1. SINE in interval [−4𝜋,4𝜋], i.e., 𝑦 = sin(𝑥), −4𝜋 ≤ 𝑥 ≤4𝜋.

# %%
# Import necessary modules

# Using math module for pi and sin function


import matplotlib.pyplot as plt

import math


# Step 1: Generate equidistant x-coordinates between the given interval

# Lists for coordinates

x = []

y = []


# Define start, end, and step size for x increment

start = -4 * math.pi

end = 4 * math.pi

step = 0.1 # Controls smoothness of the graph


i = start

while i <= end:

  x.append(i) # Store x-coordinate

  # Step 2: Calculate the y-coordinate using sin function for each x

  y.append(math.sin(i))

  i += step


# Step 3: Plot the graph using calculated coordinates

# Label the graph properly

plt.plot(x, y, color="red", label="sin function")

plt.xlabel("X")

plt.ylabel("Y")

plt.title("y = sin(x) ,-4π<= x <= 4π")

plt.grid(True)

plt.legend()

plt.show()

# %% [markdown]
# 1. Plot a circle with center at (a, b) and radius r. The values of a, b, and r can be chosen appropriately.
#
# Note: To get better result, we use the parametric equation of circle, which is given by:
#
# · 𝑥 =(𝑟cos(𝜃)+𝑎) and
#
# · 𝑦 = (𝑟sin(𝜃)+𝑏) , where 0 ≤ 𝜃 ≤2𝜋

# %%
# Task : Plot a circle with center at (a,b) and radius =r

# for a=b=2 and r = 4:

# Circle equation: x^2 + y^2 = r^2

# Paramateric equation:

# x =r*cos(theta) + a , and y = r*sin(theta) + b
x =[] # List to store x values

y= [] # List to store y values

r = 4

center = [2,2]

# paramater theta start value

theta_start = 0.0

# parameter Theta end value (bit more than 2pi)

theta_end = 2*math.pi

# step sizes to sample the paramater Theta

step_size= 0.125

#math.ceil() → round up to nearest integer

# Number of samples

steps = math.ceil((theta_end-theta_start)/step_size)

# initialize the theta

# variable to increment Theta by each step

theta = theta_start

# for loop to calculate x and y value at each steps

for i in range(0,steps):

  x.append(r*math.cos(theta)+center[0])

  y.append(r*math.sin(theta)+center[1])
  theta += step_size

# create figure in new window

plt.figure()

# plot a dot a center

plt.plot(center[0],center[1],'.')

plt.plot(x,y,'-')

plt.grid()

plt.xlabel("X")

plt.ylabel("Y")

#plt.gca() → Get the current figure (axes object) for handling

ax =plt.gca()

#ensures 1 unit in x = 1 unit in y

#Without this ,figure is stretched(ircle could appear as an ellipse)

ax.set_aspect('equal',adjustable='box')

plt.show()

# %% [markdown]
# 1. Plot an Ellipse ( ((x-p)^2)/a^2) +( ((y-q)^2)/b^2) =1 with center at (p, q), length of minor axis 2a and major axis 2b. The values of p, q, a, and b can be chosen appropriately.
#
# Note : parametric equations of an ellipse centered at (p,q) with semi-major axis b and semi-minor axis a are:
#
# · x = a cos(θ)+p,
#
# · y = b sin(θ) +q

# %%
# importing a library

import matplotlib.pyplot as plt

import math

# Lists to store x and y values

x = []

y= []

# Ellipse parameters

a=3 # semi-minor axis

b=5 # semi-major axis

center =[2,2] # center (p,q)


# Parameter theta

theta_start = 0.0

theta_end = 3*math.pi # make more than 2*pi

step_size = 0.125


# Number of samples

steps = math.ceil((theta_end -theta_start) / step_size)


# initializing theta

theta= theta_start
# calculate x and y cooradinates

for i in range(steps):

  x.append(a*math.cos(theta)+center[0]) # x= a*cos(θ) +p

  y.append(b*math.sin(theta)+center[1]) # y=b*sin(θ) +q

  theta += step_size # incremet the theta by step_size


# Plotting

plt.figure()

# plot the center point

plt.plot(center[0],center[1],'.')

#Plot the ellipse

plt.plot(x,y,'-')

plt.grid()

plt.xlabel("X")

plt.ylabel("Y")

plt.title("Ellipse centered at (2,2) with a=3 , b=5")


# Equal aspect ration to avoid stretching

ax= plt.gca()

ax.set_aspect('equal',adjustable='box')

plt.show()

# %% [markdown]
# 4. Plot a Parabola (𝑦 − 𝑝) ^2= 4𝑎(𝑥 − 𝑞) with vertex at (𝑝,𝑞). The values of p, q, and a can be chosen appropriately.

# %%
import matplotlib.pyplot as plt

import math

# parabola parameters

q=0 # y-coordinate of vertex

p=0 # x-coordinate of vertex

a=0.5 # controls width and direction

# Step size for x values

step_size = 0.1

# define x range aroung vertex

y_start = p-5

y_end = p + 5

# lists to store coordinates

x_values =[]

y_values =[]

#initialize x

y = y_start

# generate poinst for parabola
while y <= y_end:

  x = 4*a*(y-p)**2+p

  x_values.append(x)

  y_values.append(y)

  y += step_size

#plot the graph

plt.figure()

plt.title(f"Parabola with vertex at ({p},{q}) and a ={a}")

plt.plot(x_values,y_values,'-')

plt.grid()

plt.xlabel("X")

plt.ylabel("Y")

plt.show()

# %% [markdown]
# 4. Draw the line represented by the function y=x.

# %%
import numpy as np
import matplotlib.pyplot as plt
# Generate x values
x = np.linspace(-10, 10, 100)
# Define the function y=x
y=x
# Plot the line
plt.plot(x, y, label='y=x')
#Add labels and title
plt.xlabel('x')
plt.ylabel('y')
plt.title('Line Plot of y=x')
# Add grid and legend
plt.grid()
plt.legend()
#Show the plot
plt.show()

# %% [markdown]
# 5. Draw a line in a diagram that joins the position (1, 3), (2, 8), (6, 1) and (8, 10).

# %%
import matplotlib.pyplot as plt
# Given points
x = [1, 2, 6, 8]
y = [3, 8, 1, 10]
# Plot the points and join them with lines
plt.plot(x, y, marker='o')
#Label each point
for i in range(len(x)):
  plt.text(x[i], y[i], f"({x[i]}, {y[i]})")
#Add labels and title
plt.xlabel('x')
plt.ylabel('y')
plt.title('Line Joining Given Points')
#Show grid
plt.grid()
#Display the plot
plt.show()

# %% [markdown]
# 6. Plot 20 values of x and y from the following functions.
#
# 𝑓(𝑥)=5𝑥3+2𝑥−1
#
# 𝑓(𝑥)=−2𝑥3+𝑥2+100
#
# 𝑓(𝑥)=2𝜋𝑥+20

# %%
import numpy as np
import matplotlib.pyplot as plt
#Generate 20 x values
x = np.linspace(-10,10, 20)
#Define the functions
y1 = 5*x**3 + 2*x -1
y2 = -2*x**3 + x**2 + 100
y3 = 2*np.pi*x + 20
#Plot all functions
plt.plot(x, y1, marker='o', label='f(x) = 5x^3 + 2x -1')
plt.plot(x, y2, marker='s', label='f(x) = -2x^3 + x^2 +100')
plt.plot(x, y3, marker='^', label='f(x) = 2𝜋x + 20')
#Labels and title
plt.xlabel('x')
plt.ylabel('y')
plt.title('Plots of Given Functions')
plt.grid()
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 120587 (\N{MATHEMATICAL ITALIC SMALL PI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# 7. Plot all the graph from Q no 3 on the same pane using subplot.

# %%
import numpy as np
import matplotlib.pyplot as plt
#Generate x values
x = np.linspace(-10, 10, 100)
#Define y=x
y=x
#Plot the line
plt.plot(x, y, color='blue', label='y=x')
#Add labels and title
plt.xlabel('x')
plt.ylabel('y')
plt.title('Line Plot of y=x')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# 8. Plot all the graph from Task 2 using subplot.

# %%
import matplotlib.pyplot as plt
#Data from the table
days = [1, 2, 3, 4, 5]
enfield = [ 50, 40, 70, 80, 20]
honda = [80, 20, 20, 50, 60]
yahama = [70, 20, 60, 40, 60]
ktm = [40, 20, 30, 70, 60]
#Create a figure with subplots
fig, axs = plt.subplots(2, 2, figsize=(12, 8))
#Enfield plot
axs[0, 0].plot(days, enfield, marker='o', color='blue')
axs[0, 0].set_title('Enfield Distance')
axs[0, 0].set_xlabel('Days')
axs[0, 0].set_ylabel('Distance (kms)')
#Honda plot
axs[0, 1].plot(days, honda, marker='s', color='red')
axs[0, 1].set_title('Honda Distance')
axs[0, 1].set_xlabel('Days')
axs[0, 1].set_ylabel('Distance (kms)')
#Yahama plot
axs[1, 0].plot(days, yahama, marker='^', color='green')
axs[1, 0].set_title('Yahama Distance')
axs[1, 0].set_xlabel('Days')
axs[1, 0].set_ylabel('Distance (kms)')
#KTM plot
axs[1, 1].plot(days, ktm, marker='d', color='orange')
axs[1, 1].set_title('KTM Distance')
axs[1, 1].set_xlabel('Days')
axs[1, 1].set_ylabel('Distance (kms)')
#Overall title
fig.suptitle('Bike Details in Plot', fontsize=16)
#Adjust layout
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %% [markdown]
# 9. Plot the trigonometric COSINE function in interval [−3𝜋,3𝜋], i.e., 𝑦 = cos (𝑥), −3𝜋 ≤ 𝑥 ≤3𝜋

# %%
import numpy as np
import matplotlib.pyplot as plt
#Create x values from -3π to 3π
x = np.linspace(-3*np.pi, 3*np.pi, 400)
#cosine function
y = np.cos(x)
#plot
plt.figure()
plt.plot(x, y)
plt.title("Cosine Function: y = cos(x)")
plt.xlabel("x")
plt.ylabel("cos(x)")
plt.grid()
plt.show()

# %% [markdown]
# 10. Plot a circle with center at (a, b) and radius r. The values of a=b=2, and r=4, using a while loop.

# %%
import numpy as np
import matplotlib.pyplot as plt
a = 2
b = 2
r = 4
theta = 0
x = []
y = []
#using while loop
while theta <= 2*np.pi:
  x.append(a + r*np.cos(theta))
  y.append(b + r*np.sin(theta))
  theta += 0.01
#Plot circle
plt.figure()
plt.plot(x, y)
plt.gca().set_aspect('equal', adjustable='box')#make it circle
plt.title("Circle with center (2,2) and radius 4")
plt.xlabel("x")
plt.ylabel("y")
plt.grid()
plt.show()

# %% [markdown]
# 11. Plot the above circle and the ellipse on the same axes. This is give an idea about the intersection points of the two conic sections.

# %%
import numpy as np
import matplotlib.pyplot as plt
#Circle parameters
a = 2
b = 2
r = 4
#Ellipse parameters
A = 6 #semi-major axis
B = 3 #semi-minor axis
theta = np.linspace(0, 2*np.pi, 400)
#Circle
x_circle = a + r*np.cos(theta)
y_circle = b + r*np.sin(theta)
#ellipse
x_ellipse = a + A*np.cos(theta)
y_ellipse = b + B*np.sin(theta)
#plot both
plt.figure()
plt.plot(x_circle, y_circle, label="Circle")
plt.plot(x_ellipse, y_ellipse, label="Ellipse")
plt.gca().set_aspect('equal', adjustable='box')
plt.title("Circle and Ellipse on Same Axes")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# 12. Plot a Parabola (𝑦 − 𝑝) = 4𝑎(𝑥 − 𝑞)^2 with vertex at (𝑝,𝑞). The values of p, q, and a can be chosen appropriately.

# %%
import numpy as np
import matplotlib.pyplot as plt
#choose values
p = 1
q = 2
a = 0.5
#x values
x = np.linspace(-5, 5, 400)
#parabola equation:(𝑦 − 𝑝) = 4𝑎(𝑥 − 𝑞)^2
y = p + 4*a*(x -q)**2
#Plot
plt.figure()
plt.plot(x, y, label="Parabola")
plt.scatter(q, p, color='red', label="vertex")
plt.title("Parabola with vertex at (p,q)")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid()
plt.show()
